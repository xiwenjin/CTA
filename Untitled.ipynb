# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import KalmanFilter as kf

import matplotlib.pyplot as plt

import mplfinance as fplt
import backtrader as bt

# %%
url = r'C:\Users\User921\Desktop\RCM\strats\data\ActiveContractRolling.xlsx'
sse50 = pd.read_excel(url, sheet_name='SSE50') .sort_values('Date').dropna().set_index('Date')
csi500 = pd.read_excel(url, sheet_name='CSI500').sort_values('Date').dropna().set_index('Date')
csi300 = pd.read_excel(url, sheet_name='CSI300').sort_values('Date').dropna().set_index('Date')

wti = pd.read_excel(url, sheet_name='WTI') .sort_values('Date').dropna().set_index('Date')
brt = pd.read_excel(url, sheet_name='Brent') .sort_values('Date').dropna().set_index('Date')

# %% [markdown]
# # Indicators

# %%
class indicators:
    def __init__(self):
        pass
        
    def EMA(self, price, days):       
        if not isinstance(price, pd.core.series.Series):
            raise Exception('The input prices should be object of pandas with datetime as index.')
            
        if price.index[0] < price.index[-1]:
            price = price.sort_index()      
        
        return price.ewm(span=days).mean()
    
    def MACD(self, price, fast, slow, sig):
        macd = self.EMA(price, fast) - self.EMA(price, slow)
        avg = self.EMA(macd, sig)
        hist = macd - avg
        
        return macd, avg, hist
    
    def reverse_signals(self, price, ds):
        pos, buy, sell = False, [], []
        
        ds = ds.diff(1)
        for i in ds.index[1:]:
            if not pos:
                if ds[i] > 0:
                    buy.append([i, price[i]])
                    sell.append([i, None])
                    pos = '+'
                elif ds[i] < 0:
                    sell.append([i, price[i]])
                    buy.append([i, None])
                    pos = '-'
                else:
                    continue
            else:
                if pos == '+':
                    buy.append([i, None])
                    if ds[i] >= 0:
                        sell.append([i, None])
                    if ds[i] < 0:
                        sell.append([i, price[i]])
                        pos = '-'
                else:
                    sell.append([i, None])
                    if ds[i] <= 0:
                        buy.append([i, None])
                    if ds[i] > 0:
                        buy.append([i, price[i]])
                        pos = '+'
                        
        b_sig, s_sig = pd.DataFrame({'date': ds.index[0], 'Close': [None]}), \
                       pd.DataFrame({'date': ds.index[0], 'Close': [None]})          
        
        buy = pd.concat([b_sig, pd.DataFrame({'date': list(zip(*buy))[0], 
                                            'Close': list(zip(*buy))[1]})]).set_index('date')
        sell = pd.concat([s_sig, pd.DataFrame({'date': list(zip(*sell))[0],
                                              'Close': list(zip(*sell))[1]})]).set_index('date')
        return buy, sell

# %% [markdown]
# # simple back test

# %%
class myDataFeed(bt.feeds.PandasData):
    lines = ('macd', 'signal', 'hist')
    params = (('macd', -1), ('signal', -1), ('hist', -1))


class myStrat(bt.Strategy):
    params = (('fast', 12), ('slow', 26), ('sig', 9), ('col', 'hist'))
    
    def log(self, msg, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print(str(dt.isoformat()) + ', ' + msg)
    
    def __init__(self):
        '''
        loc: which column to use as indicator
        '''
        self.dataclose = self.datas[0].close
        self.ind = self.datas[0]._getline(self.p.col)
        self.order = None
        
        self.buy_price = None
        self.buy_comm = None
        self.sell_price = None
        self.sell_comm = None
        
        self.const_size = 1
        
        # count the iteration of next()
        self.ct = 0
        
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                # print order info
                self.log('Buy exe @ ' + str(np.round(order.executed.price, 2)) +\
                         ', Cost: ' + str(np.round(order.executed.value, 2)) +\
                         ', Commision: ' + str(np.round(order.executed.comm, 2)) +\
                         ', Position: ' + str(self.position.size))
                
                # record executed price
                self.buy_price = order.executed.price
                self.buy_comm = order.executed.comm
            else:
                self.log('Sell exe @ ' + str(np.round(order.executed.price, 2)) +\
                         ', Cost: ' + str(np.round(order.executed.value, 2)) +\
                         ', Commision: ' + str(np.round(order.executed.comm, 2)) +\
                         ', Position: ' + str(self.position.size))
                
                # record executed price
                self.sell_price = order.executed.price
                self.sell_comm = order.executed.comm
                
            self.bar_executed = len(self)
                
        if order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
            
        self.order = None
            
    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        self.log('Gross PnL: ' + str(np.round(trade.pnl, 2)) +\
                 ', Net PnL: ' + str(np.round(trade.pnlcomm, 2)))
        
    
    def next(self):
        self.ct += 1
        self.log('Close price: ' + str(self.dataclose[0]) +\
                 ', Balance: ' + str(np.round(self.stats.broker.value[0], 2)))

        # if order is submitted or pending, we do nothing.
        if self.order:
            return
        
        if not self.position:
            if self.ct > 1: # when self.ct = 0, self.ind[-1] is last indicator in the data feed
                if self.ind[0] > self.ind[-1]:
                    self.log('Signal: Open Buy @ ' + str(self.dataclose[0]))
                    self.order = self.buy(size=self.const_size)
                elif self.ind[0] < self.ind[-1]:
                    self.log('Signal: Open Sell @ ' + str(self.dataclose[0]))
                    self.order = self.sell(size=self.const_size)
                else: 
                    return
            else:
                return 
        else:        
            if self.ind[0] > self.ind[-1]:
                if self.position.size < 0:
                    self.log('Signal: Exit & Buy @ ' + str(self.dataclose[0]))
                    self.order = self.buy(size=self.const_size * 2)
                else:
                    return
                    
            elif self.ind[0] < self.ind[-1]:
                if self.position.size > 0:                    
                    self.log('Signal: Exit & Sell @ ' + str(self.dataclose[0]))
                    self.order = self.sell(size=self.const_size * 2)
                else:
                    return
            else:
                return

# %%
yr = 2018
start, end = pd.datetime(yr, 1, 1), pd.datetime(yr, 12, 31)

d50, d300, d500 = sse50[start: end], csi300[start: end], csi500[start: end]
dwti, dbrt = wti[start: end], brt[start: end]

idx = d500[:]

ind = indicators()
fast = 12
slow = 26
sig = 9

macd, avg, hist = ind.MACD(idx.Close, fast, slow, sig)
idx['macd'], idx['signal'], idx['hist'] = macd, avg, hist

buy, sell = ind.reverse_signals(idx.Close, hist)

# %%
add = [fplt.make_addplot(hist, type='bar', color='grey', alpha=0.3),
       fplt.make_addplot(macd, type='line', color='red', alpha=0.3, panel=1),
       fplt.make_addplot(avg, type='line', color='green', alpha=0.3, panel=1),
       fplt.make_addplot(buy, type='scatter', marker='^', color='green'),
       fplt.make_addplot(sell, type='scatter', marker='v', color='red'),]
       
fplt.plot(idx, type='line', style='charles', 
          volume=False, figratio=(16,8), addplot=add)

# %%
cbro = bt.Cerebro(stdstats=True)
cbro.addstrategy(myStrat, col='hist')

# data = bt.feeds.PandasData(dataname=idx,
#                            fromdate=start,
#                            todate=end,
#                            plot=False)

# init data feed with my own indicators
data = myDataFeed(dataname=d500,
                  fromdate=start,
                  todate=end,
                  plot=False)
# data.plotinfo.subplot = True


cbro.adddata(data)
cbro.addobserver(bt.observers.Broker)
cbro.broker.setcommission(commission=10, margin=True, mult=200)
# cbro.broker.set_slippage_perc(5e-3)

# assume order executed on the close of the bar that the same bar the signal is generated,
# as the indicator is calculated using open prices.
# cbro.broker.set_coc(True)
cbro.broker.setcash(1e+6)

print('Starting balance:', str(cbro.broker.getvalue()))

cbro.run()

print('Ending balance:', str(cbro.broker.getvalue()))
# Out:
# Starting balance: 1000000.0
# 2018-01-02, Close price: 4381.11, Balance: nan
# 2018-01-03, Close price: 4414.68, Balance: 1000000.0
# 2018-01-04, Close price: 4422.82, Balance: 1000000.0
# 2018-01-05, Close price: 4424.62, Balance: 1000000.0
# 2018-01-08, Close price: 4440.92, Balance: 1000000.0
# 2018-01-09, Close price: 4435.67, Balance: 1000000.0
# 2018-01-10, Close price: 4416.47, Balance: 1000000.0
# 2018-01-11, Close price: 4439.68, Balance: 1000000.0
# 2018-01-12, Close price: 4416.33, Balance: 1000000.0
# 2018-01-15, Close price: 4328.77, Balance: 1000000.0
# 2018-01-16, Close price: 4336.92, Balance: 1000000.0
# 2018-01-17, Close price: 4329.98, Balance: 1000000.0
# 2018-01-18, Close price: 4341.77, Balance: 1000000.0
# 2018-01-19, Close price: 4332.06, Balance: 1000000.0
# 2018-01-22, Close price: 4406.87, Balance: 1000000.0
# 2018-01-23, Close price: 4400.9, Balance: 1000000.0
# 2018-01-24, Close price: 4453.09, Balance: 1000000.0
# 2018-01-25, Close price: 4443.24, Balance: 1000000.0
# 2018-01-26, Close price: 4439.49, Balance: 1000000.0
# 2018-01-29, Close price: 4377.45, Balance: 1000000.0
# 2018-01-30, Close price: 4377.17, Balance: 1000000.0
# 2018-01-31, Close price: 4286.95, Balance: 1000000.0
# 2018-02-01, Close price: 4158.69, Balance: 1000000.0
# 2018-02-02, Close price: 4152.17, Balance: 1000000.0
# 2018-02-05, Close price: 4149.67, Balance: 1000000.0
# 2018-02-06, Close price: 3979.08, Balance: 1000000.0
# 2018-02-07, Close price: 3948.27, Balance: 1000000.0
# 2018-02-08, Close price: 3991.36, Balance: 1000000.0
# 2018-02-09, Close price: 3824.98, Balance: 1000000.0
# 2018-02-12, Close price: 3950.64, Balance: 1000000.0
# 2018-02-13, Close price: 3964.3, Balance: 1000000.0
# 2018-02-14, Close price: 3973.51, Balance: 1000000.0
# 2018-02-22, Close price: 4056.21, Balance: 1000000.0
# 2018-02-23, Close price: 4061.51, Balance: 1000000.0
# 2018-02-26, Close price: 4180.33, Balance: 1000000.0
# 2018-02-27, Close price: 4178.93, Balance: 1000000.0
# 2018-02-28, Close price: 4178.38, Balance: 1000000.0
# 2018-03-01, Close price: 4216.59, Balance: 1000000.0
# 2018-03-02, Close price: 4200.97, Balance: 1000000.0
# 2018-03-05, Close price: 4193.3, Balance: 1000000.0
# 2018-03-06, Close price: 4251.87, Balance: 1000000.0
# 2018-03-07, Close price: 4215.47, Balance: 1000000.0
# 2018-03-08, Close price: 4248.52, Balance: 1000000.0
# 2018-03-09, Close price: 4319.93, Balance: 1000000.0
# 2018-03-12, Close price: 4378.78, Balance: 1000000.0
# 2018-10-31, Close price: 3171.22, Balance: 1000000.0
# 2018-11-01, Close price: 3192.43, Balance: 1000000.0
# 2018-11-02, Close price: 3295.5, Balance: 1000000.0
# 2018-11-05, Close price: 3284.29, Balance: 1000000.0
# 2018-11-06, Close price: 3294.75, Balance: 1000000.0
# 2018-11-07, Close price: 3278.02, Balance: 1000000.0
# 2018-11-08, Close price: 3258.75, Balance: 1000000.0
# 2018-11-09, Close price: 3251.28, Balance: 1000000.0
# 2018-11-12, Close price: 3330.15, Balance: 1000000.0
# 2018-11-13, Close price: 3413.06, Balance: 1000000.0
# 2018-11-14, Close price: 3386.17, Balance: 1000000.0
# 2018-11-15, Close price: 3443.53, Balance: 1000000.0
# 2018-11-16, Close price: 3476.69, Balance: 1000000.0
# 2018-11-19, Close price: 3470.56, Balance: 1000000.0
# 2018-11-20, Close price: 3378.25, Balance: 1000000.0
# 2018-11-21, Close price: 3381.24, Balance: 1000000.0
# 2018-11-22, Close price: 3387.21, Balance: 1000000.0
# 2018-11-23, Close price: 3254.12, Balance: 1000000.0
# 2018-11-26, Close price: 3222.15, Balance: 1000000.0
# 2018-11-27, Close price: 3230.52, Balance: 1000000.0
# 2018-11-28, Close price: 3288.48, Balance: 1000000.0
# 2018-11-29, Close price: 3225.59, Balance: 1000000.0
# 2018-11-30, Close price: 3230.52, Balance: 1000000.0
# 2018-12-03, Close price: 3341.36, Balance: 1000000.0
# 2018-12-04, Close price: 3367.5, Balance: 1000000.0
# 2018-12-05, Close price: 3346.28, Balance: 1000000.0
# 2018-12-06, Close price: 3278.02, Balance: 1000000.0
# 2018-12-07, Close price: 3280.11, Balance: 1000000.0
# 2018-12-10, Close price: 3243.66, Balance: 1000000.0
# 2018-12-11, Close price: 3255.47, Balance: 1000000.0
# 2018-12-12, Close price: 3271.6, Balance: 1000000.0
# 2018-12-13, Close price: 3313.42, Balance: 1000000.0
# 2018-12-14, Close price: 3238.59, Balance: 1000000.0
# 2018-12-17, Close price: 3224.69, Balance: 1000000.0
# 2018-12-18, Close price: 3211.85, Balance: 1000000.0
# 2018-12-19, Close price: 3166.95, Balance: 1000000.0
# 2018-12-20, Close price: 3170.7, Balance: 1000000.0
# 2018-12-21, Close price: 3136.92, Balance: 1000000.0
# 2018-12-24, Close price: 3189.92, Balance: 1000000.0
# 2018-12-25, Close price: 3157.19, Balance: 1000000.0
# 2018-12-26, Close price: 3144.57, Balance: 1000000.0
# 2018-12-27, Close price: 3117.85, Balance: 1000000.0
# 2018-12-28, Close price: 3101.63, Balance: 1000000.0
# Ending balance: 1000000.0

# %%
plt.rcParams['figure.figsize']=[14, 6]
cbro.plot()
# Out:
# <img src="data:image/png;base64,..." width="1008.1817963300663">
# [[<Figure size 1008x432 with 3 Axes>]]

# %% [markdown]
# # with filtering

# %%
# set up design matrix
# assume state process: x_t = x_{t-1} + w_t, w ~ N(0, Q)
# measurement process: y_t = x_t + e_t, e ~ N(0, R)
# inital state: x0 = first observation and p0 = std of close price during previous 1 month.
A = 1
B = 0
H = 1
Q = 1 #csi500.loc[pd.datetime(yr-1, 12, 1): pd.datetime(yr-1, 12, 31), 'Close'].std()
R = 100

# calc filtered macd and signal lines
x, P = idx.macd[0], 1

k_filter = kf.KalmanFilter(A, B, H, Q, R)
macd_ftd, _, _, _ = k_filter.filt(idx.macd, x, P)
macd_ftd = k_filter.to_array(macd_ftd)

signal_ftd, _, _, _ = k_filter.filt(idx.signal, x, P)
signal_ftd = k_filter.to_array(signal_ftd)

hist_ftd = pd.Series(macd_ftd - signal_ftd, index=idx.index)
buy, sell = ind.reverse_signals(idx.Close, hist_ftd)

# %%
# %matplotlib inline
add = [fplt.make_addplot(macd_ftd, type='line', color='red', alpha=0.3, panel=1),
       fplt.make_addplot(signal_ftd, type='line', color='green', alpha=0.3, panel=1),
       fplt.make_addplot(hist_ftd, type='bar', color='grey', alpha=0.3, panel=0),
       fplt.make_addplot(buy, type='scatter', marker='^', color='green'),
       fplt.make_addplot(sell, type='scatter', marker='v', color='red'),]
       
fplt.plot(idx, type='line', style='charles', 
          volume=False, figratio=(16,8), addplot=add)

# %%
# calc indicator using filtered price
Q = csi500.loc[pd.datetime(yr-1, 12, 1): pd.datetime(yr-1, 12, 31), 'Close'].std()
R = 1
idx = d500[:]
x, P = idx.Close[0], 10

updates, _, _, _ = k_filter.filt(idx.Close, x, P)
updates = pd.Series(updates, index=idx.index)
macd, avg, hist = ind.MACD(updates, fast, slow, sig)
idx['macd_ftd'], idx['signal_ftd'], idx['hist_ftd'] = macd, avg, hist
buy, sell = ind.reverse_signals(idx.Close, hist)

# %%
add = [fplt.make_addplot(hist, type='bar', color='grey', alpha=0.3),
       fplt.make_addplot(macd, type='line', color='red', alpha=0.3, panel=1),
       fplt.make_addplot(avg, type='line', color='green', alpha=0.3, panel=1),
       fplt.make_addplot(updates, type='line', color='green', alpha=0.3, panel=0),
       fplt.make_addplot(buy, type='scatter', marker='^', color='green'),
       fplt.make_addplot(sell, type='scatter', marker='v', color='red'),]
       
fplt.plot(idx, type='line', style='charles', 
          volume=False, figratio=(16,8), addplot=add)

# %%
# using filtered hist 
Q = idx['hist'].diff(1).std()
R = 1
idx = d500[:]
macd, avg, hist = ind.MACD(idx.Close, fast, slow, sig)
idx['macd'], idx['signal'], idx['hist'] = macd, avg, hist

x, P = idx['hist'][0], 10
hist_ftd, _, _, _ = k_filter.filt(idx['hist'], x, P)
k_filter.to_array(hist_ftd)

idx['hist_ftd'] = k_filter.to_array(hist_ftd)
buy, sell = ind.reverse_signals(idx.Close, idx.hist_ftd)

# %%
plt.figure(figsize=(10, 5))
plt.plot(idx['hist'], label='hist')
plt.plot(idx.hist_ftd, label='filtered')
plt.legend(loc='best')

# %%
add = [fplt.make_addplot(idx.hist_ftd, type='bar', color='grey', alpha=0.3),
       fplt.make_addplot(macd, type='line', color='red', alpha=0.3, panel=1),
       fplt.make_addplot(avg, type='line', color='green', alpha=0.3, panel=1),
       fplt.make_addplot(buy, type='scatter', marker='^', color='green'),
       fplt.make_addplot(sell, type='scatter', marker='v', color='red'),]
       
fplt.plot(idx, type='line', style='charles', 
          volume=False, figratio=(16,8), addplot=add)
